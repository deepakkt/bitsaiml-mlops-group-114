# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook is optional; the reproducible EDA pipeline lives in `src/heart/eda.py` and can be run headlessly with `python -m src.heart.eda` (see `make eda`). Generated figures are saved to `report/figures/`.
#
# Use this notebook for ad-hoc exploration or to embed the generated plots in a report.
